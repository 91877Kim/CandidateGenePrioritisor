# %%
#@title CloudMap3 • local notebook: no-mapping prioritization with MCM context (single block)

# =========================
# Setup (installs + imports)
# =========================
# You may comment the next line on repeat runs.
#%pip -q install --upgrade "pydantic>=2,<3" pandas python-dateutil requests tabulate > /dev/null

import os, re, json, math, time, pathlib, textwrap
from typing import List, Dict, Any, Optional, Tuple
import requests
import pandas as pd
from pydantic import BaseModel, Field, ValidationError, conint, confloat, field_validator
from datetime import datetime, timezone
from tabulate import tabulate

# =========================
# API keys (local hardcoded)
# =========================
OPENAI_API_KEY = "PUT_YOUR_OPENAI_API_KEY_HERE"
NCBI_API_KEY = "PUT_YOUR_NCBI_API_KEY_HERE"  # optional

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
if NCBI_API_KEY and NCBI_API_KEY != "PUT_YOUR_NCBI_API_KEY_HERE":
    os.environ["NCBI_API_KEY"] = NCBI_API_KEY

# =========================
# Paths
# =========================
CSV_PATH = "drp5.csv"  # @param {type:"string"}

def _with_fallback(p: str, candidates: List[str]) -> str:
    pth = pathlib.Path(p)
    if pth.exists():
        return str(pth)
    for c in candidates:
        if pathlib.Path(c).exists():
            print(f"[Info] Using fallback file: {c}")
            return c
    return str(pth)

CSV_PATH = _with_fallback(
    CSV_PATH,
    ["drp5.csv", "drp5 (1).csv"]
)

# =========================
# Model and run parameters
# =========================
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL", "https://api.openai.com/v1")
OPENAI_MODEL    = os.getenv("OPENAI_MODEL", "gpt-5-mini")

OPENAI_TEMPERATURE = os.getenv("OPENAI_TEMPERATURE", "")   # leave empty to auto-adapt
OPENAI_SEED        = os.getenv("OPENAI_SEED", "")
OPENAI_TIMEOUT     = int(os.getenv("OPENAI_TIMEOUT", "360"))
OPENAI_MAX_RETRIES = int(os.getenv("OPENAI_MAX_RETRIES", "5"))
OPENAI_BACKOFF_BASE= float(os.getenv("OPENAI_BACKOFF_BASE", "2.0"))

TOP_K                = 30        # how many to keep in ranking
MAX_VARIANTS_TO_SEND = 250
RUN_ID = datetime.now(timezone.utc).strftime("%Y%m%d-%H%M%S")

OUTPUT_DIR = pathlib.Path("llm_variant_prioritization_outputs")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# =========================
# Networking helpers (robust)
# =========================
def _requests_get(url: str, params: Dict[str, Any], timeout: int = 30, retries: int = 3, backoff: float = 2.0):
    for i in range(retries):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            r.raise_for_status()
            return r
        except Exception as e:
            if i == retries - 1:
                raise
            time.sleep(backoff ** i)

def _requests_post_with_retries(url: str, headers: Dict[str, str], payload: Dict[str, Any],
                                timeout: int, max_retries: int, backoff_base: float) -> requests.Response:
    attempt = 0
    while True:
        try:
            return requests.post(url, headers=headers, json=payload, timeout=timeout)
        except (requests.exceptions.ReadTimeout,
                requests.exceptions.ConnectTimeout,
                requests.exceptions.ConnectionError,
                requests.exceptions.ChunkedEncodingError):
            if attempt >= max_retries - 1:
                raise
            time.sleep(backoff_base ** attempt)
            attempt += 1

def _post_chat(payload: Dict[str, Any], timeout: int = OPENAI_TIMEOUT) -> str:
    headers = {"Authorization": f"Bearer {os.environ['OPENAI_API_KEY']}", "Content-Type": "application/json"}
    r = _requests_post_with_retries(
        f"{OPENAI_BASE_URL}/chat/completions",
        headers=headers, payload=payload, timeout=timeout,
        max_retries=OPENAI_MAX_RETRIES, backoff_base=OPENAI_BACKOFF_BASE
    )
    if r.status_code != 200:
        raise RuntimeError(f"OpenAI error {r.status_code}: {r.text[:2000]}")
    data = r.json()
    return data["choices"][0]["message"]["content"]

def openai_chat(messages: List[Dict[str, str]],
                model: str,
                response_json: bool = True,
                temperature: Optional[float] = None,
                seed: Optional[int] = None,
                timeout: int = OPENAI_TIMEOUT) -> str:
    payload: Dict[str, Any] = {"model": model, "messages": messages}
    if response_json:
        payload["response_format"] = {"type": "json_object"}
    if temperature is not None:
        payload["temperature"] = float(temperature)
    if seed is not None:
        payload["seed"] = int(seed)
    try:
        return _post_chat(payload, timeout=timeout)
    except RuntimeError as err:
        body = str(err)
        retried = False
        if ("param" in body and "temperature" in body) or ("Unsupported value" in body and "temperature" in body):
            payload.pop("temperature", None); retried = True
        if ("param" in body and "\"seed\"" in body):
            payload.pop("seed", None); retried = True
        if ("param" in body and "response_format" in body) or ("json_object" in body):
            payload.pop("response_format", None); retried = True
        if retried:
            return _post_chat(payload, timeout=timeout)
        raise

# =========================
# CSV loading + key builders
# =========================
def exists_or_raise(p: str):
    if not pathlib.Path(p).exists():
        raise FileNotFoundError(
            f"File not found: {p}\n"
            "• Place the CSV in the project folder (or provide a full path).\n"
            "• Then set CSV_PATH accordingly."
        )

def coalesce(colnames: List[str], df: pd.DataFrame) -> Optional[str]:
    for c in colnames:
        if c in df.columns: return c
    return None

def normalize_chr_label(chrom: Any) -> str:
    s = str(chrom)
    s = re.sub(r'(?i)^chromosome\s*', '', s)
    s = re.sub(r'(?i)^chr', '', s)
    s = s.strip()
    map_arabic = {"1":"I","2":"II","3":"III","4":"IV","5":"V","10":"X"}
    if s in map_arabic: return map_arabic[s]
    return s.upper()

def build_variant_id(chrom, pos, ref, alt) -> str:
    c = normalize_chr_label(chrom) if pd.notna(chrom) else "NA"
    p = str(int(pos)) if pd.notna(pos) else "NA"
    r = str(ref).upper() if pd.notna(ref) else "N"
    a = str(alt).upper() if pd.notna(alt) else "N"
    return f"{c}:{p} {r}>{a}"

def short(s: Any, maxlen: int = 60) -> str:
    t = "" if s is None else str(s)
    return t if len(t) <= maxlen else (t[:maxlen-1] + "…")

def normalize_float(s: pd.Series, clamp01: bool = False) -> pd.Series:
    out = pd.to_numeric(s, errors="coerce")
    if clamp01:
        out = out.clip(lower=0.0, upper=1.0)
    return out

# =========================
# Load primary annotated CSV
# =========================
exists_or_raise(CSV_PATH)
df = pd.read_csv(CSV_PATH)
print(f"Loaded {len(df):,} variants from: {CSV_PATH}")

# Column discovery (primary)
chrom_col = coalesce(["CHROM", "Chrom", "chr", "chrom", "#CHROM"], df) or "CHROM"
pos_col   = coalesce(["POS", "Position", "POS_GRCh", "pos"], df) or "POS"
ref_col   = coalesce(["REF", "Ref", "reference_allele", "ref"], df)
alt_col   = coalesce(["ALT", "Alt", "alt_allele", "alt"], df)
qual_col  = coalesce(["qual", "quality", "Quality", "QUALITY", "Qual", "QUAL"], df)
gene_col   = coalesce(["Gene_name", "Gene", "GENE", "SYMBOL", "Symbol", "GeneName", "ANN_Gene_Name", "HGNC"], df)
effect_col = coalesce(["Effect", "Consequence", "ANN_Consequence", "ANN_Annotation", "VEP_CONSEQUENCE"], df)
impact_col = coalesce(["IMPACT", "Impact", "ANN_Annotation_Impact", "VEP_IMPACT"], df)
aa_col     = coalesce(["HGVSp", "HGVSp_Short", "AAChange", "Protein_change", "HGVS.p"], df)
sift_col   = coalesce(["SIFT", "SIFT_pred", "SIFT_PRED"], df)
pphen_col  = coalesce(["PolyPhen", "PolyPhen_pred", "PolyPhen_PRED"], df)
info_col   = coalesce(["INFO", "info"], df)

# Build standardized keys for primary
df.columns = [c.strip() for c in df.columns]
df["_CHROM_N"] = df[chrom_col].apply(normalize_chr_label)
df["_POS_I"]   = pd.to_numeric(df[pos_col], errors="coerce").astype("Int64")
if ref_col:
    df["_REF_U"] = df[ref_col].astype(str).str.upper()
else:
    df["_REF_U"] = "N"
if alt_col:
    df["_ALT_U"] = df[alt_col].astype(str).str.upper()
else:
    df["_ALT_U"] = "N"
df["variant_id"] = df.apply(lambda r: build_variant_id(r["_CHROM_N"], r["_POS_I"], r["_REF_U"], r["_ALT_U"]), axis=1)
df["pos_key"]    = df["_CHROM_N"].astype(str) + ":" + df["_POS_I"].astype(str)

if not impact_col:
    impact_col = "IMPACT"
    df[impact_col] = pd.NA
if not effect_col:
    effect_col = "EFFECT"
    df[effect_col] = pd.NA
if not gene_col:
    gene_col = "GENE_NAME"
    df[gene_col] = pd.NA

if qual_col:
    df["QUALITY"] = pd.to_numeric(df[qual_col], errors="coerce")
else:
    df["QUALITY"] = pd.NA

def _extract_ann_first(info_val: Any) -> Tuple[str, str, str]:
    txt = "" if info_val is None else str(info_val)
    m = re.search(r"(?:^|;)ANN=([^;]+)", txt)
    if not m:
        return "", "", ""
    first_ann = m.group(1).split(",")[0]
    parts = first_ann.split("|")
    effect = parts[1] if len(parts) > 1 else ""
    impact = parts[2] if len(parts) > 2 else ""
    gene = parts[3] if len(parts) > 3 else ""
    return effect, impact, gene

if info_col:
    ann_df = df[info_col].apply(_extract_ann_first).apply(pd.Series)
    ann_df.columns = ["_ANN_EFFECT", "_ANN_IMPACT", "_ANN_GENE"]
    df = pd.concat([df, ann_df], axis=1)

    missing_effect = df[effect_col].isna() | (df[effect_col].astype(str).str.strip() == "")
    missing_impact = df[impact_col].isna() | (df[impact_col].astype(str).str.strip() == "")
    missing_gene = df[gene_col].isna() | (df[gene_col].astype(str).str.strip() == "")

    df.loc[missing_effect, effect_col] = df.loc[missing_effect, "_ANN_EFFECT"]
    df.loc[missing_impact, impact_col] = df.loc[missing_impact, "_ANN_IMPACT"]
    df.loc[missing_gene, gene_col] = df.loc[missing_gene, "_ANN_GENE"]

# =========================
# Build records and deduplicate by severity
# =========================
def effect_severity_score(effect_text: str, impact_bucket: str) -> float:
    t = (effect_text or "").lower()
    base = {"HIGH": 3.0, "MODERATE": 2.0, "LOW": 1.0, "UNKNOWN": 0.5}.get((impact_bucket or "UNKNOWN").upper(), 0.5)
    if any(k in t for k in ["stop_gained","frameshift","splice_acceptor","splice_donor","start_lost","stop_lost","exon_loss"]):
        base = max(base, 3.2)
    elif any(k in t for k in ["missense","inframe_insertion","inframe_deletion","protein_altering"]):
        base = max(base, 2.2)
    elif any(k in t for k in ["synonymous","upstream","downstream","utr","intron"]):
        base = min(base, 1.0)
    return float(base)

def impact_bucket_from(effect_text: str, impact_bucket: Optional[str]) -> str:
    if isinstance(impact_bucket, str) and impact_bucket:
        ib = impact_bucket.strip().upper()
        if ib in {"HIGH","MODERATE","LOW"}:
            return ib
    t = (effect_text or "").lower()
    if any(k in t for k in ["stop_gained","frameshift","splice_acceptor","splice_donor","start_lost","stop_lost"]): return "HIGH"
    if any(k in t for k in ["missense","inframe_insertion","inframe_deletion","protein_altering"]): return "MODERATE"
    if any(k in t for k in ["synonymous","upstream","downstream","utr","intron"]): return "LOW"
    return "UNKNOWN"

def coerce_float(x):
    try: return float(x)
    except Exception: return None

packed_all: List[Dict[str, Any]] = []
for _, row in df.iterrows():
    vid = row["variant_id"]
    pkey = row["pos_key"]
    gene = row.get(gene_col) if gene_col else None
    effect = row.get(effect_col) if effect_col else None
    ib = impact_bucket_from(effect, row.get(impact_col) if impact_col in df.columns else None)

    rec = {
        "variant_id": vid,
        "pos_key": pkey,
        "chrom": row["_CHROM_N"],
        "pos": int(row["_POS_I"]) if pd.notna(row["_POS_I"]) else None,
        "gene": (gene if pd.notna(gene) else "") if gene is not None else "",
        "effect": effect if pd.notna(effect) else "",
        "impact_bucket": ib,
        "protein_change": short(row.get(aa_col), 48) if aa_col else "",
        "sift": short(row.get(sift_col), 28) if sift_col else "",
        "polyphen": short(row.get(pphen_col), 28) if pphen_col else "",
        "qual": row.get("QUALITY"),
    }

    imp_w = {"HIGH": 0.45, "MODERATE": 0.25, "LOW": 0.05, "UNKNOWN": 0.0}.get(rec["impact_bucket"], 0.0)
    q = rec["qual"]
    q_w = 0.0 if (q is None or (isinstance(q, float) and math.isnan(q))) else min(float(q), 200) / 200.0 * 0.05
    rec["_pre_score"] = imp_w + q_w
    rec["_severity"] = effect_severity_score(rec["effect"], rec["impact_bucket"])
    packed_all.append(rec)

# Deduplicate by variant_id, keeping most severe/relevant
def tie_break_key(r):
    q = r.get("qual") or 0.0
    return (r["_severity"], q)

packed_dedup: List[Dict[str, Any]] = []
for vid, grp in pd.DataFrame(packed_all).groupby("variant_id"):
    best = max(grp.to_dict("records"), key=tie_break_key)
    packed_dedup.append(best)
packed_df = pd.DataFrame(packed_dedup)
print(f"Prepared base records for {len(packed_df):,} variants after dedup by most severe effect.")

# =========================
# Pre-filter for LLM
# =========================
pref = sorted(packed_dedup, key=lambda r: (r["_pre_score"], r["_severity"]), reverse=True)[:MAX_VARIANTS_TO_SEND]
print(f"Will send {len(pref):,} variants to GPT-5-mini (MAX_VARIANTS_TO_SEND={MAX_VARIANTS_TO_SEND}).")

# =========================
# Lightweight gene-knowledge fetch (NCBI Gene summary + PubMed refs)
# =========================
def fetch_gene_knowledge(gene: str) -> Dict[str, Any]:
    gene = (gene or "").strip()
    if not gene:
        return {"summary": "", "refs": []}

    # NCBI Gene summary
    api_key = os.getenv("NCBI_API_KEY", "")
    params_es = {"db": "gene", "retmode": "json", "term": f"{gene}[Gene Name] AND Caenorhabditis elegans[Organism]"}
    if api_key:
        params_es["api_key"] = api_key
    summary_text = ""
    refs = []

    try:
        es = _requests_get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi", params_es, timeout=20)
        js = es.json()
        ids = js.get("esearchresult", {}).get("idlist", [])
        if ids:
            gid = ids[0]
            params_sum = {"db": "gene", "retmode": "json", "id": gid}
            if api_key:
                params_sum["api_key"] = api_key
            su = _requests_get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi", params_sum, timeout=20).json()
            doc = su.get("result", {}).get(gid, {})
            summary_text = doc.get("summary", "") or doc.get("description", "")
    except Exception:
        pass

    try:
        q = f'({gene}) AND ("mystery cell of male" OR MCM OR neuron) AND elegans'
        params_pm = {"db": "pubmed", "retmode": "json", "retmax": "3", "sort": "relevance", "term": q}
        if api_key:
            params_pm["api_key"] = api_key
        pm = _requests_get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi", params_pm, timeout=20).json()
        idlist = pm.get("esearchresult", {}).get("idlist", [])[:3]
        if idlist:
            params_sm = {"db": "pubmed", "retmode": "json", "id": ",".join(idlist)}
            if api_key:
                params_sm["api_key"] = api_key
            sm = _requests_get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi", params_sm, timeout=20).json()
            for pid in idlist:
                it = sm.get("result", {}).get(pid, {})
                title = it.get("title", "")
                url = f"https://pubmed.ncbi.nlm.nih.gov/{pid}/"
                if title:
                    refs.append({"pmid": pid, "title": title, "url": url})
    except Exception:
        pass

    return {"summary": summary_text.strip(), "refs": refs}

# Build knowledge map for unique genes in 'pref'
unique_genes = sorted({(r.get("gene") or "").strip() for r in pref if r.get("gene")})
gene_knowledge: Dict[str, Dict[str, Any]] = {}
for g in unique_genes:
    try:
        gene_knowledge[g] = fetch_gene_knowledge(g)
    except Exception:
        gene_knowledge[g] = {"summary": "", "refs": []}

# =========================
# LLM schemas
# =========================
class VariantRankItem(BaseModel):
    rank: conint(ge=1)
    variant_id: str
    gene: Optional[str] = ""
    causal_probability: confloat(ge=0, le=1)
    confidence: confloat(ge=0, le=1)
    rationale: str
    key_evidence: List[str] = Field(default_factory=list)

class VariantNarrative(BaseModel):
    variant_id: str
    gene: Optional[str] = ""
    narrative: str
    narrative_confidence: confloat(ge=0, le=1)

class LLMVariantOutput(BaseModel):
    summary: str
    most_likely: VariantRankItem
    ranking: List[VariantRankItem]
    annotations: List[VariantNarrative]

    @field_validator("ranking")
    @classmethod
    def non_empty_rank(cls, v):
        if not v: raise ValueError("ranking must be non-empty")
        return v
    @field_validator("annotations")
    @classmethod
    def non_empty_ann(cls, v):
        if not v: raise ValueError("annotations must be non-empty")
        return v

class LLMRankingOnly(BaseModel):
    summary: str
    most_likely: VariantRankItem
    ranking: List[VariantRankItem]

def try_parse_json(s: str) -> Dict[str, Any]:
    try:
        return json.loads(s)
    except Exception:
        m = re.search(r"\{[\s\S]*\}", s)
        if m:
            return json.loads(m.group(0))
        raise

# =========================
# Build prompts (allow gene knowledge + references)
# =========================
SYSTEM_PROMPT_MAIN = """You are an expert in C. elegans forward genetics and mystery cells of male (MCM) fate.

Context:
- Screen detects loss of MCM neurons via a GFP reporter.
- Goal: identify variants most likely to cause MCM loss.

Evidence you may use:
- Structured fields: Gene_name, Effect, impact_bucket, protein_change, QUAL, SIFT, PolyPhen.
- Gene knowledge: brief summaries and PubMed links (if provided) for the gene's known/putative function in C. elegans or related biology.

Instructions:
- Rank variants by causal probability (0-1) and provide confidence (0-1).
- For each variant, write a 2-5 sentence narrative connecting the mutation and gene function to MCM loss.
- Cite evidence in brackets, e.g., [Effect=stop_gained; impact_bucket=HIGH; QUAL=41.2; GeneRef: PMID 12345, 67890].
- Prefer HIGH-impact (nonsense/frameshift/essential splice) > damaging missense > low/unknown; use QUAL as secondary support.
- Do not fabricate references; only cite provided PubMed links. Output JSON only; no chain-of-thought."""
def format_variant_for_llm(r: Dict[str, Any]) -> Dict[str, Any]:
    def safe_round(x, nd=3):
        try:
            return round(float(x), nd)
        except Exception:
            return None

    g = (r.get("gene") or "").strip()
    gk = gene_knowledge.get(g, {"summary": "", "refs": []})
    return {
        "variant_id": r["variant_id"],
        "Gene_name": g,
        "Effect": short(r.get("effect"), 90),
        "impact_bucket": r.get("impact_bucket", "UNKNOWN"),
        "protein_change": short(r.get("protein_change", ""), 48),
        "QUAL": safe_round(r.get("qual"), 1),
        "SIFT": r.get("sift", ""),
        "PolyPhen": r.get("polyphen", ""),
        "_pre_score": round(float(r.get("_pre_score", 0.0)), 3),
        "gene_knowledge": {
            "summary": short(gk.get("summary", ""), 480),
            "pubmed_refs": gk.get("refs", []),
        },
    }

variants_for_llm = [format_variant_for_llm(r) for r in pref]

USER_PROMPT_MAIN = {
    "task": "Prioritize variants for mystery cells of male (MCM) loss and annotate each with a narrative + confidence leveraging gene function and provided PubMed links.",
    "instructions": {
        "ranking_size": min(TOP_K, len(variants_for_llm)),
        "return_all_ranked": True,
        "notes": [
            "Use provided gene summaries and PubMed refs if present; otherwise rely on mutation class + general neuronal mechanisms.",
            "Narratives 2-5 sentences; include bracketed evidence and [GeneRef: PMID ...] when refs provided."
        ],
    },
    "schema": {
        "summary": "string",
        "most_likely": {
            "rank": 1,
            "variant_id": "string",
            "gene": "string",
            "causal_probability": 0.00,
            "confidence": 0.00,
            "rationale": "string",
            "key_evidence": ["short bullet strings"],
        },
        "ranking": [
            {
                "rank": 1,
                "variant_id": "string",
                "gene": "string",
                "causal_probability": 0.00,
                "confidence": 0.00,
                "rationale": "string",
                "key_evidence": ["short bullet strings"],
            }
        ],
        "annotations": [
            {
                "variant_id": "string",
                "gene": "string",
                "narrative": "string",
                "narrative_confidence": 0.00,
            }
        ],
    },
    "variants": variants_for_llm,
}
# =========================
# Call LLM (single-shot, then fallback)
# =========================
def single_shot_call() -> Optional[LLMVariantOutput]:
    temp_val = float(OPENAI_TEMPERATURE) if OPENAI_TEMPERATURE.strip() else None
    seed_val = int(OPENAI_SEED) if OPENAI_SEED.strip() else None
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT_MAIN},
        {"role": "user", "content": json.dumps(USER_PROMPT_MAIN, ensure_ascii=False, separators=(",", ":"))}
    ]
    print(f"Calling {OPENAI_MODEL} with {len(variants_for_llm)} variants (single-shot)…")
    raw = openai_chat(messages, model=OPENAI_MODEL, response_json=True, temperature=temp_val, seed=seed_val, timeout=OPENAI_TIMEOUT)
    parsed = try_parse_json(raw)
    return LLMVariantOutput(**parsed)

# Fallback: chunked narratives + ranking from summaries
NARR_SYSTEM = """You are an expert in C. elegans mystery cells of male biology.
For each variant, write a 2-5 sentence narrative using provided fields and gene summaries/PMIDs if present.
Cite evidence in brackets, e.g., [Effect=missense; impact_bucket=MODERATE; QUAL=22.1; GeneRef: PMID 12345].
Return JSON: {"annotations":[{variant_id, gene, narrative, narrative_confidence}, ...]}"""
def llm_narratives_in_chunks(items: List[Dict[str, Any]], chunk_size: int = 18) -> Dict[str, Tuple[str, float]]:
    out: Dict[str, Tuple[str, float]] = {}
    for i in range(0, len(items), chunk_size):
        chunk = items[i:i+chunk_size]
        user = {
            "variants": chunk,
            "schema": {
                "annotations": [
                    {
                        "variant_id": "string",
                        "gene": "string",
                        "narrative": "string",
                        "narrative_confidence": 0.00,
                    }
                ]
            },
        }
        messages = [
            {"role": "system", "content": NARR_SYSTEM},
            {"role": "user", "content": json.dumps(user, ensure_ascii=False, separators=(",", ":"))}
        ]
        raw = openai_chat(messages, model=OPENAI_MODEL, response_json=True, temperature=None, seed=None, timeout=OPENAI_TIMEOUT)
        parsed = try_parse_json(raw)
        anns = parsed.get("annotations", [])
        for a in anns:
            try:
                va = VariantNarrative(**a)
                out[va.variant_id] = (va.narrative, float(va.narrative_confidence))
            except ValidationError:
                pass
    return out

RANK_SYSTEM = """Rank variants for causing mystery cells of male loss using only provided summaries.
Heuristics: HIGH-impact > damaging missense > low/unknown; QUAL supports confidence; integrate narratives and narrative confidence.
Output JSON only with fields: summary, most_likely, ranking[]."""
def llm_ranking_from_summaries(summaries: List[Dict[str, Any]]) -> LLMRankingOnly:
    user = {
        "task": "Rank all variants by likelihood of causing mystery cells of male loss.",
        "top_k": min(TOP_K, len(summaries)),
        "variant_summaries": summaries,
        "schema": {
            "summary": "string",
            "most_likely": {
                "rank": 1, "variant_id": "string", "gene": "string",
                "causal_probability": 0.00, "confidence": 0.00,
                "rationale": "string", "key_evidence": ["short strings"]
            },
            "ranking": [
                {"rank": 1, "variant_id": "string", "gene": "string","causal_probability": 0.00, "confidence": 0.00,"rationale": "string", "key_evidence": ["short strings"]}
            ]
        }
    }
    messages = [
        {"role": "system", "content": RANK_SYSTEM},
        {"role": "user", "content": json.dumps(user, ensure_ascii=False, separators=(",", ":"))}
    ]
    raw = openai_chat(messages, model=OPENAI_MODEL, response_json=True, temperature=None, seed=None, timeout=OPENAI_TIMEOUT)
    parsed = try_parse_json(raw)
    return LLMRankingOnly(**parsed)

def chunked_fallback_pipeline() -> Tuple[pd.DataFrame, Dict[str, Tuple[str,float]]]:
    print("Falling back to chunked pipeline: generating narratives in chunks…")
    narr_map = llm_narratives_in_chunks(variants_for_llm, chunk_size=18)
    print("Chunked pipeline: ranking from compact summaries…")
    summaries = []
    for v in variants_for_llm:
        vid = v["variant_id"]
        narrative, narr_conf = narr_map.get(vid, ("", 0.0))
        summaries.append({
            "variant_id": vid,
            "gene": v.get("Gene_name", ""),
            "Effect": v.get("Effect", ""),
            "impact_bucket": v.get("impact_bucket", "UNKNOWN"),
            "protein_change": v.get("protein_change", ""),
            "QUAL": v.get("QUAL", None),
            "SIFT": v.get("SIFT", ""),
            "PolyPhen": v.get("PolyPhen", ""),
            "gene_knowledge": v.get("gene_knowledge", {}),
            "narrative": narrative,
            "narrative_confidence": narr_conf,
            "_pre_score": v.get("_pre_score", 0.0),
        })
    ranking_only = llm_ranking_from_summaries(summaries)
    rank_rows = []
    for it in sorted(ranking_only.ranking, key=lambda x: x.rank)[:TOP_K]:
        rank_rows.append({
            "run_id": RUN_ID,
            "variant_id": it.variant_id,
            "gene": it.gene,
            "rank": int(it.rank),
            "causal_probability": round(float(it.causal_probability), 2),
            "confidence": round(float(it.confidence), 2),
            "rationale": it.rationale,
            "key_evidence": "; ".join(it.key_evidence) if it.key_evidence else "",
            "Narrative": narr_map.get(it.variant_id, ("", None))[0],
            "Narrative_confidence": round(narr_map.get(it.variant_id, ("", 0.0))[1], 2) if it.variant_id in narr_map else None,
        })
    return pd.DataFrame(rank_rows).sort_values(["rank","variant_id"]), narr_map

# =========================
# Execute: single-shot, else chunked fallback
# =========================
rank_df: Optional[pd.DataFrame] = None
narr_map: Dict[str, Tuple[str, float]] = {}

try:
    llm_out = single_shot_call()
    narr_map = {a.variant_id: (a.narrative, float(a.narrative_confidence)) for a in llm_out.annotations}
    ranked = sorted(llm_out.ranking, key=lambda x: x.rank)
    if TOP_K and len(ranked) > TOP_K:
        ranked = ranked[:TOP_K]
    rows = []
    for it in ranked:
        rows.append({
            "run_id": RUN_ID,
            "variant_id": it.variant_id,
            "gene": it.gene,
            "rank": int(it.rank),
            "causal_probability": round(float(it.causal_probability), 2),
            "confidence": round(float(it.confidence), 2),
            "rationale": it.rationale,
            "key_evidence": "; ".join(it.key_evidence) if it.key_evidence else "",
            "Narrative": narr_map.get(it.variant_id, ("", None))[0],
            "Narrative_confidence": round(narr_map.get(it.variant_id, ("", 0.0))[1], 2) if it.variant_id in narr_map else None,
        })
    rank_df = pd.DataFrame(rows).sort_values(["rank","variant_id"])
except Exception as e:
    print(f"[Single-shot failed: {e.__class__.__name__}] {e}\n")
    rank_df, narr_map = chunked_fallback_pipeline()

# =========================
# Save artifacts
# =========================
csv_path = OUTPUT_DIR / f"llm_variant_ranking_{RUN_ID}.csv"
jsonl_path = OUTPUT_DIR / f"llm_variant_ranking_{RUN_ID}.jsonl"
rank_df.to_csv(csv_path, index=False)
with open(jsonl_path, "w", encoding="utf-8") as f:
    for _, r in rank_df.iterrows():
        f.write(json.dumps(dict(r), ensure_ascii=False) + "\n")

# Merge back selected original fields for convenient viewing (from packed_dedup)
orig_small = pd.DataFrame(packed_dedup).copy()
orig_small_ren = orig_small[[
    "variant_id", "gene", "effect", "impact_bucket", "protein_change", "sift", "polyphen", "qual"
]].rename(columns={"gene": "Gene_name_csv", "effect": "Effect_csv"})

final_df = (
    rank_df.merge(orig_small_ren, how="left", on="variant_id")
    .sort_values(["rank", "variant_id"])
)

view_cols = [
    "rank", "causal_probability", "confidence",
    "variant_id", "gene", "Gene_name_csv", "Effect_csv", "impact_bucket", "protein_change", "sift", "polyphen", "qual",
    "Narrative", "Narrative_confidence", "rationale", "key_evidence"
]
final_df = final_df[[c for c in view_cols if c in final_df.columns]]

# =========================
# Display summary
# =========================
print("\n=== Top ranked variants (preview) ===")
print(tabulate(final_df.head(20).fillna(""), headers="keys", tablefmt="github", showindex=False))

if not rank_df.empty:
    top_row = rank_df.sort_values("rank").iloc[0]
    print("\n=== Most likely causal variant (LLM) ===")
    print(tabulate([[
        int(top_row["rank"]), top_row["variant_id"], top_row["gene"],
        f"{float(top_row['causal_probability']):.2f}", f"{float(top_row['confidence']):.2f}",
        textwrap.shorten(str(narr_map.get(top_row["variant_id"], ("", 0.0))[0]), width=120),
        f"{float(narr_map.get(top_row['variant_id'], ('', 0.0))[1]):.2f}"
    ]], headers=["rank","variant_id","gene","prob","conf","narrative","narr_conf"], tablefmt="github"))

merged_path = OUTPUT_DIR / f"llm_variant_ranking_merged_{RUN_ID}.csv"
final_df.to_csv(merged_path, index=False)

print(f"\nWROTE:\n- {csv_path.resolve()}\n- {jsonl_path.resolve()}\n- {merged_path.resolve()}")

# =========================
# Output diagnostics
# =========================
missing_counts = {
    "gene": int(final_df["gene"].isna().sum() if "gene" in final_df.columns else 0),
    "effect": int(final_df["Effect_csv"].isna().sum() if "Effect_csv" in final_df.columns else 0),
    "impact_bucket": int(final_df["impact_bucket"].isna().sum() if "impact_bucket" in final_df.columns else 0),
    "qual": int(final_df["qual"].isna().sum() if "qual" in final_df.columns else 0),
    "narrative": int(final_df["Narrative"].isna().sum() if "Narrative" in final_df.columns else 0),
}
print("\n[Post-merge diagnostics] Missing-by-column:")
print(missing_counts)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ϵͳ�Ҳ���ָ����·����
# Loaded 240 variants from: drp5.csv
# Loaded user annotations from user_file.csv
# Prepared base records for 240 variants after dedup by most severe effect.
# Will send 240 variants to GPT‑5‑mini (FILTER_MIN_PARENTAL_RATIO=0.4, MAX_VARIANTS_TO_SEND=250).
# [PubMed] unique_genes: 182; sample: 21ur-10687, 21ur-12819, 21ur-13251, 21ur-13377, 21ur-14257
# [PubMed] 1/182: 21ur-10687
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 10/182: 21ur-5655
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 20/182: C11E4.16
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 30/182: D2092.13
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 40/182: F48F5.7
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 50/182: M162.7
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 60/182: Y105E8A.2
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 70/182: Y38A10A.7
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 80/182: Y50D4A.6
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 90/182: Y71F9AR.8
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [PubMed] 100/182: Y97E10B.12
# []
# []
# [{'pmid': '35800971', 'title': 'Molecular lesions in alleles of the Caenorhabditis elegans lin-11 gene.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/35800971/'}]
# [{'pmid': '28982592', 'title': 'Human amyloid β peptide and tau co-expression impairs behavior and causes specific gene expression changes in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/28982592/'}]
# [{'pmid': '32524554', 'title': 'Generation and Analysis of CCM Phenotypes in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/32524554/'}, {'pmid': '30996251', 'title': 'A conserved CCM complex promotes apoptosis non-autonomously by regulating zinc homeostasis.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/30996251/'}]
# [{'pmid': '40383750', 'title': 'CDK-4 regulates nucleolar size and metabolism at the cost of late-life fitness in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/40383750/'}, {'pmid': '25562820', 'title': 'Rb and FZR1/Cdh1 determine CDK4/6-cyclin D requirement in C. elegans and human cancer cells.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/25562820/'}, {'pmid': '22102824', 'title': 'Caenorhabditis elegans cyclin D/CDK4 and cyclin E/CDK2 induce distinct cell cycle re-entry programs in differentiated muscle cells.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/22102824/'}]
# [{'pmid': '20150279', 'title': 'The HMX/NKX homeodomain protein MLS-2 specifies the identity of the AWC sensory neuron type via regulation of the ceh-36 Otx gene in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/20150279/'}, {'pmid': '25738873', 'title': 'The Bicoid class homeodomain factors ceh-36/OTX and unc-30/PITX cooperate in C. elegans embryonic progenitor cells to regulate robust development.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/25738873/'}, {'pmid': '15095973', 'title': 'The C. elegans ceh-36 gene encodes a putative homemodomain transcription factor involved in chemosensory functions of ASE and AWC neurons.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/15095973/'}]
# []
# [{'pmid': '23695300', 'title': 'Defining specificity determinants of cGMP mediated gustatory sensory transduction in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/23695300/'}]
# []
# [PubMed] 110/182: chkr-2
# []
# [{'pmid': '37186867', 'title': 'C. elegans Clarinet/CLA-1 recruits RIMB-1/RIM-binding protein and UNC-13 to orchestrate presynaptic neurotransmitter release.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37186867/'}, {'pmid': '37389488', 'title': 'The active zone protein CLA-1 (Clarinet) bridges two subsynaptic domains to regulate presynaptic sorting of ATG-9.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37389488/'}, {'pmid': '37053235', 'title': 'The active zone protein Clarinet regulates synaptic sorting of ATG-9 and presynaptic autophagy.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37053235/'}]
# []
# []
# [{'pmid': '37122503', 'title': 'CRISPR-activated expression of collagen col-120 increases lifespan and heat tolerance.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37122503/'}]
# [{'pmid': '31242447', 'title': 'Genetic markers enable the verification and manipulation of the dauer entry decision.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/31242447/'}]
# []
# []
# []
# [{'pmid': '23966152', 'title': 'The decapping scavenger enzyme DCS-1: a new modulator of miRNA turnover.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/23966152/'}, {'pmid': '23541767', 'title': 'The decapping scavenger enzyme DCS-1 controls microRNA levels in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/23541767/'}, {'pmid': '16207815', 'title': 'Caenorhabditis elegans decapping proteins: localization and functional analysis of Dcp1, Dcp2, and DcpS during embryogenesis.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/16207815/'}]
# [PubMed] 120/182: dsl-3
# [{'pmid': '23124064', 'title': 'Essential role for Notch signaling in restricting developmental plasticity.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/23124064/'}]
# []
# [{'pmid': '30810526', 'title': 'EFHC1, implicated in juvenile myoclonic epilepsy, functions at the cilium and synapse to modulate dopamine signaling.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/30810526/'}]
# [{'pmid': '18806786', 'title': 'FMRFamide neuropeptides and acetylcholine synergistically inhibit egg-laying by C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/18806786/'}, {'pmid': '29579048', 'title': 'Oxygen-sensing neurons reciprocally regulate peripheral lipid metabolism via neuropeptide signaling in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/29579048/'}, {'pmid': '23152612', 'title': 'IRK-1 potassium channels mediate peptidergic inhibition of Caenorhabditis elegans serotonin neurons via a G(o) signaling pathway.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/23152612/'}]
# []
# []
# []
# []
# []
# []
# [PubMed] 130/182: gck-3
# [{'pmid': '20595048', 'title': 'The Caenorhabditis elegans Ste20 kinase, GCK-3, is essential for postembryonic developmental timing and regulates meiotic chromosome segregation.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/20595048/'}, {'pmid': '18049475', 'title': 'Caenorhabditis elegans WNK-STE20 pathway regulates tube formation by modulating ClC channel activity.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/18049475/'}, {'pmid': '23083714', 'title': 'CLC anion channel regulatory phosphorylation and conserved signal transduction domains.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/23083714/'}]
# [{'pmid': '31159140', 'title': 'Tris(1,3-dichloro-2-propyl) phosphate accelerated the aging process induced by the 4-hydroxynon-2-enal response to reactive oxidative species in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/31159140/'}]
# []
# []
# []
# []
# []
# [{'pmid': '36261532', 'title': 'HRG-9 homologues regulate haem trafficking from haem-enriched compartments.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/36261532/'}, {'pmid': '38106020', 'title': "Heme's relevance genuine? Re-visiting the roles of TANGO2 homologs including HRG-9 and HRG-10 in C. elegans.", 'url': 'https://pubmed.ncbi.nlm.nih.gov/38106020/'}, {'pmid': '41504601', 'title': 'Cross-species evaluation of TANGO2 homologs, including HRG-9 and HRG-10 in Caenorhabditis elegans, challenges a proposed role in heme trafficking.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/41504601/'}]
# [{'pmid': '37961478', 'title': 'Chromokinesin Klp-19 regulates microtubule overlap and dynamics during anaphase in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37961478/'}, {'pmid': '15452142', 'title': 'Loss of KLP-19 polar ejection force causes misorientation and missegregation of holocentric chromosomes.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/15452142/'}, {'pmid': '38150489', 'title': 'Redundant microtubule crosslinkers prevent meiotic spindle bending to ensure diploid offspring in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/38150489/'}]
# [{'pmid': '38218270', 'title': 'A comprehensive review on DDX3X liquid phase condensation in health and neurodevelopmental disorders.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/38218270/'}]
# [PubMed] 140/182: lgc-26
# []
# []
# [{'pmid': '30737265', 'title': 'Heterochromatic foci and transcriptional repression by an unstructured MET-2/SETDB1 co-factor LIN-65.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/30737265/'}, {'pmid': '30140741', 'title': 'Regulated nuclear accumulation of a histone methyltransferase times the onset of heterochromatin formation in C. elegans embryos.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/30140741/'}, {'pmid': '16624904', 'title': 'Identification and classification of genes that act antagonistically to let-60 Ras signaling in Caenorhabditis elegans vulval development.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/16624904/'}]
# []
# []
# []
# [{'pmid': '20109220', 'title': 'Characterization of the astacin family of metalloproteases in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/20109220/'}, {'pmid': '14653817', 'title': 'The astacin protein family in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/14653817/'}]
# []
# [{'pmid': '32294113', 'title': 'Disruption of genes associated with Charcot-Marie-Tooth type 2 lead to common behavioural, cellular and molecular defects in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/32294113/'}, {'pmid': '39395417', 'title': 'Neuropeptide inactivation regulates egg-laying behavior to influence reproductive health in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/39395417/'}, {'pmid': '20929849', 'title': 'Olfactory plasticity is regulated by pheromonal signaling in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/20929849/'}]
# []
# [PubMed] 150/182: nfki-1
# [{'pmid': '28099418', 'title': 'IL-17 is a neuromodulator of Caenorhabditis elegans sensory responses.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/28099418/'}]
# []
# [{'pmid': '21712952', 'title': 'The adiponectin receptor homologs in C. elegans promote energy utilization and homeostasis.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/21712952/'}]
# []
# []
# [{'pmid': '21549604', 'title': 'C. elegans Notch signaling regulates adult chemosensory response and larval molting quiescence.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/21549604/'}]
# [{'pmid': '37463170', 'title': 'Multiple pals gene modules control a balance between immunity and development in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37463170/'}, {'pmid': '36711775', 'title': 'Multiple pals gene modules control a balance between immunity and development in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/36711775/'}]
# []
# [{'pmid': '39103170', 'title': 'Comparative analysis of new mScarlet-based red fluorescent tags in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/39103170/'}, {'pmid': '34389721', 'title': 'Mapping the biosynthetic pathway of a hybrid polyketide-nonribosomal peptide in a metazoan.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/34389721/'}, {'pmid': '38915494', 'title': 'Comparative analysis of new, mScarlet-based red fluorescent tags in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/38915494/'}]
# [{'pmid': '36219157', 'title': 'β-heavy-spectrin stabilizes the constricting contractile ring during cytokinesis.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/36219157/'}, {'pmid': '28400443', 'title': 'Plastin increases cortical connectivity to facilitate robust polarization and timely cytokinesis.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/28400443/'}]
# [PubMed] 160/182: pqn-83
# []
# [{'pmid': '16876152', 'title': 'Alterations in ribosome biogenesis cause specific defects in C. elegans hermaphrodite gonadogenesis.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/16876152/'}]
# [{'pmid': '19244614', 'title': 'A LIM-9 (FHL)/SCPL-1 (SCP) complex interacts with the C-terminal protein kinase regions of UNC-89 (obscurin) in Caenorhabditis elegans muscle.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/19244614/'}, {'pmid': '23283987', 'title': 'CPNA-1, a copine domain protein, is located at integrin adhesion sites and is required for myofilament stability in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/23283987/'}, {'pmid': '18337465', 'title': 'A novel protein phosphatase is a binding partner for the protein kinase domains of UNC-89 (Obscurin) in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/18337465/'}]
# [{'pmid': '37930961', 'title': 'PGP-14 establishes a polar lipid permeability barrier within the C. elegans pharyngeal cuticle.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37930961/'}, {'pmid': '38704027', 'title': 'Sphingolipid profiling reveals differential functions of sphingolipid biosynthesis isozymes of Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/38704027/'}, {'pmid': '31477732', 'title': 'The marginal cells of the Caenorhabditis elegans pharynx scavenge cholesterol and other hydrophobic small molecules.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/31477732/'}]
# [{'pmid': '24749077', 'title': 'LET-418/Mi2 and SPR-5/LSD1 cooperatively prevent somatic reprogramming of C. elegans germline stem cells.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/24749077/'}, {'pmid': '17047361', 'title': 'Presenilin function in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/17047361/'}, {'pmid': '40991443', 'title': 'Ectopic transcription due to inherited histone methylation may interfere with the ongoing function of differentiated neurons.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/40991443/'}]
# [{'pmid': '37497183', 'title': 'A missense mutation in the C. elegans src-2 tyrosine-protein kinase reduces brood size and enhances embryonic morphogenesis defects in src-1(RNAi) conditions.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37497183/'}, {'pmid': '12527374', 'title': 'Distinct roles of the Src family kinases, SRC-1 and KIN-22, that are negatively regulated by CSK-1 in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/12527374/'}, {'pmid': '26777275', 'title': 'A Two-Immunoglobulin-Domain Transmembrane Protein Mediates an Epidermal-Neuronal Interaction to Maintain Synapse Density.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/26777275/'}]
# []
# []
# []
# []
# [PubMed] 170/182: str-176
# []
# [{'pmid': '32957927', 'title': 'SWI/SNF complexes act through CBP-1 histone acetyltransferase to regulate acute functional tolerance to alcohol.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/32957927/'}, {'pmid': '29786685', 'title': 'Regulation of chromatin states and gene expression during HSN neuronal maturation is mediated by EOR-1/PLZF, MAU-2/cohesin loader, and SWI/SNF complex.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/29786685/'}]
# []
# []
# [{'pmid': '20346955', 'title': 'Extensive and modular intrinsically disordered segments in C. elegans TTN-1 and implications in filament binding, elasticity and oblique striation.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/20346955/'}, {'pmid': '18337465', 'title': 'A novel protein phosphatase is a binding partner for the protein kinase domains of UNC-89 (Obscurin) in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/18337465/'}, {'pmid': '18390597', 'title': 'Single-molecule force spectroscopy reveals a stepwise unfolding of Caenorhabditis elegans giant protein kinase domains.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/18390597/'}]
# []
# [{'pmid': '37160370', 'title': 'Active Zone Trafficking of CaV2/UNC-2 Channels Is Independent of β/CCB-1 and α2δ/UNC-36 Subunits.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37160370/'}, {'pmid': '12878695', 'title': 'Critical residues of the Caenorhabditis elegans unc-2 voltage-gated calcium channel that affect behavioral and physiological properties.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/12878695/'}, {'pmid': '16927961', 'title': 'Invertebrate modeling of a migraine channelopathy.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/16927961/'}]
# [{'pmid': '36378164', 'title': 'Channel-independent function of UNC-9/Innexin in spatial arrangement of GABAergic synapses in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/36378164/'}, {'pmid': '19432959', 'title': 'Interactions between innexins UNC-7 and UNC-9 mediate electrical synapse specificity in the Caenorhabditis elegans locomotory nervous system.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/19432959/'}, {'pmid': '37452027', 'title': 'The head mesodermal cell couples FMRFamide neuropeptide signaling with rhythmic muscle contraction in C. elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/37452027/'}]
# [{'pmid': '33766022', 'title': 'H3K27 modifiers regulate lifespan in C. elegans in a context-dependent manner.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/33766022/'}, {'pmid': '27602485', 'title': 'Increasing Notch signaling antagonizes PRC2-mediated silencing to promote reprograming of germ cells into neurons.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/27602485/'}]
# [{'pmid': '39603226', 'title': 'Nematodes exposed to furfural acetone exhibit a species-specific vacuolar H(+)-ATPase response.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/39603226/'}, {'pmid': '34311841', 'title': 'miR-1 coordinately regulates lysosomal v-ATPase and biogenesis to impact proteotoxicity and muscle function during aging.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/34311841/'}, {'pmid': '16402360', 'title': 'Functional and phenotypic relevance of differentially expressed proteins in calcineurin mutants of Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/16402360/'}]
# [PubMed] 180/182: vig-1
# [{'pmid': '40829802', 'title': 'The kinase GSK-3 alters the RNA-binding protein landscape of lipid metabolism transcripts leading to altered expression in the C. elegans nervous system.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/40829802/'}]
# [{'pmid': '21688204', 'title': 'Differential physiological roles of ESCRT complexes in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/21688204/'}, {'pmid': '22558469', 'title': 'RAB-7 antagonizes LET-23 EGFR signaling during vulva development in Caenorhabditis elegans.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/22558469/'}]
# [PubMed] 182/182: vwa-8
# [{'pmid': '32656508', 'title': 'C. elegans VWA-8 is a mitochondrial protein.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/32656508/'}, {'pmid': '32656509', 'title': 'A null mutation of C. elegans vwa-8.', 'url': 'https://pubmed.ncbi.nlm.nih.gov/32656509/'}]
# Calling gpt-5-mini with 240 variants (single-shot)…
#
# === Top ranked variants (preview) ===
# |   rank |   causal_probability |   confidence | variant_id              | GENE_NAME   | WB_Overview                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              | MANUAL_DESCRIPTION_WB                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              | EFFECT                  | Narrative                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |   Narrative_confidence | rationale                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | user_annotation   |
# |--------|----------------------|--------------|-------------------------|-------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------|
# |      1 |                 0.9  |         0.85 | X:13516823 C>T          | cdk-4       | Enables protein serine/threonine kinase activity. Involved in several processes, including G1/S transition of mitotic cell cycle; developmental process involved in reproduction; and positive regulation of cell cycle process. Part of cyclin D1-CDK4 complex. Expressed in gonad; intestine; neurons; and vulva. Used to study cancer. Human ortholog(s) of this gene implicated in several diseases, including carcinoma (multiple); central nervous system cancer (multiple); and urinary system cancer (multiple). Is an ortholog of human CDK4 (cyclin dependent kinase 4) and CDK6 (cyclin dependent kinase 6).                                                                                                                                                                  | cdk-4 encodes two isoforms of a cyclin-dependent serine/threonine protein kinase orthologous to human CDK4 and CDK6 (OMIM:123829 and OMIM:603368, mutated in cutanous malignant melanoma) which complex with D-type cyclins to regulate progression through the G1 phase of the cell cycle; CDK-4 activity is essential for G1 progression in postembryonic blast cells and as a result, cdk-4 mutant animals generally arrest during larval stages; the lethality generated by cdk mutations, also seen in animals doubly mutant for cdk-4 and cyd-1, a C. elegans D-type cyclin, can be suppressed by mutations in lin-35/Rb suggesting that, as in other organisms, LIN-35/Rb may be a major target of CDK-4/CYD-1 kinase activity; CDK-4 expression is first detected in neuronal and hypodermal lineages during mid-to-late embryogenesis, with postembryonic expression detected in hypodermal seam cells, cells of the P lineage which will give rise to ventral cord neurons, and cells of the somatic gonad, the vulva, and the intestine.                                                                                                                                                                                | missense_variant        | CDK-4 is a cyclin-dependent serine/threonine kinase required for G1 progression in postembryonic blast cells; a missense change in cdk-4 could directly block the AMso postembryonic division that produces MCM neurons, matching the Class II phenotype. The variant is a MODERATE-impact missense with good quality (QUAL=43.9), and literature shows CDK-4/CYD-1 activity is essential for G1 progression in postembryonic blast cells [Effect=missense_variant; IMPACT=MODERATE; QUALITY=43.9; MANUAL_DESCRIPTION_WB: cdk-4 required for G1 progression in postembryonic blast cells; GeneRef: PMID 40383750,25562820,22102824]. |                   0.85 | CDK-4 is a cyclin-dependent kinase required for G1 progression of postembryonic blast cells; a missense change in cdk-4 is therefore a strong mechanistic candidate to block the AMso postembryonic division that generates MCM. The variant is a high-quality (QUAL=43.9) missense with MODERATE predicted impact and cdk-4 mutants are known to arrest postembryonic divisions and larval development (CDK-4/CYD-1 pathway) [Effect=missense_variant; IMPACT=MODERATE; QUALITY=43.9; MANUAL_DESCRIPTION_WB: cdk-4 required for G1 progression in postembryonic blast cells; GeneRef: PMID 40383750,25562820,22102824]. |                   |
# |      2 |                 0.6  |         0.4  | IV:693430 C>CA          | Y55F3C.17   | Predicted to enable microtubule binding activity. Predicted to be involved in translational initiation. Predicted to be located in cytoskeleton.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | no manual description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              | frameshift_variant      | This frameshift (HIGH impact) lies in a gene predicted to bind microtubules; loss of a microtubule-binding factor can impair spindle assembly or function and thus block mitosis of the AMso cell. The variant has low read-quality (QUAL=5.0), so the allele requires validation, but the frameshift nature gives a plausible loss-of-function mechanism for preventing AMso division [Effect=frameshift_variant; IMPACT=HIGH; QUALITY=5.0; WB_Overview: predicted microtubule binding activity].                                                                                                                                   |                   0.4  | This is a predicted frameshift (HIGH impact) in a gene annotated for microtubule binding; loss of a microtubule-binding protein can impair mitotic spindle function and prevent AMso division. The low variant quality (QUAL=5.0) reduces confidence but the mutation class (frameshift) makes this a plausible causal allele if true [Effect=frameshift_variant; IMPACT=HIGH; QUALITY=5.0; WB_Overview: predicted microtubule binding activity].                                                                                                                                                                        |                   |
# |      3 |                 0.4  |         0.3  | X:13407133 C>T          | cyp-13B1    | Predicted to enable heme binding activity; iron ion binding activity; and oxidoreductase activity. Human ortholog(s) of this gene implicated in several diseases, including Ghosal hematodiaphyseal syndrome; familial Mediterranean fever; and leukemia (multiple). Is an ortholog of several human genes including CYP3A4 (cytochrome P450 family 3 subfamily A member 4); CYP3A5 (cytochrome P450 family 3 subfamily A member 5); and CYP3A7 (cytochrome P450 family 3 subfamily A member 7).                                                                                                                                                                                                                                                                                         | cyp-13B1 encodes one of ~80 C. elegans cytochrome P450s: membrane-associated, heme-containing NADPH-dependent monooxygenases that catalyze the oxidative metabolism of a variety of exogenous compounds and endogenous substrates.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 | stop_gained             | A stop_gained (HIGH impact) truncates a cytochrome P450 family enzyme (cyp-13B1). While P450s are metabolic enzymes and not canonical cell-cycle regulators, truncation could alter steroid/ligand metabolism or other signalling molecules that regulate developmental timing or division competence; the variant is high-quality (QUAL=50.4) but the link to AMso-specific division is indirect [Effect=stop_gained; IMPACT=HIGH; QUALITY=50.4; MANUAL_DESCRIPTION_WB: cyp-13B1, membrane-associated heme-containing monooxygenase].                                                                                               |                   0.3  | This is a high-confidence (QUAL=50.4) stop_gained (HIGH impact) in a cytochrome P450. P450s are generally metabolic enzymes; a truncation could alter hormone or small-molecule signalling that secondarily affects AMso division, but there is no direct evidence linking cyp-13B1 to cell-cycle control in glia. The molecular effect is strong but functional relevance to AMso division is uncertain [Effect=stop_gained; IMPACT=HIGH; QUALITY=50.4; MANUAL_DESCRIPTION_WB: membrane-associated heme-containing monooxygenase].                                                                                      |                   |
# |      4 |                 0.35 |         0.35 | II:1323150 ACCCCCCCCC>A | vig-1       | Predicted to enable RNA binding activity. Part of RISC complex. Expressed in neurons. Is an ortholog of human HABP4 (hyaluronan binding protein 4) and SERBP1 (SERPINE1 mRNA binding protein 1).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | vig-1 encodes a predicted RNA-binding protein orthologous to Drosophila VIG (Vasa Intronic Gene); vig-1 activity is required for proper function of the let-7 miRNA in vivo and thus, for regulating the transition from late larval to adult cell fates; VIG-1 is a component of the 250 kDa RNA-induced silencing complex (RISC) complex and co-immunoprecipates with both TSN-1, the C. elegans Tudor-SN ortholog, and the let-7 miRNA.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | splice_region_variant   | VIG-1 is an RNA-binding component of RISC and is required for proper let-7 miRNA function and timing of developmental transitions; a splice-region/intronic change could alter vig-1 expression or splicing and thereby disrupt developmental timing cues required for the AMso to undergo its postembryonic division. The variant is annotated as splice_region/intron (LOW impact) and functional follow-up would be required to test effects on miRNA regulation [Effect=splice_region_variant&intron_variant; IMPACT=LOW; QUALITY=22.1; MANUAL_DESCRIPTION_WB: vig-1 required for let-7 function]. [GeneRef: PMID 40829802]      |                   0.35 | VIG-1 is an RNA-binding component of RISC and modulates let-7 miRNA function; let-7 and miRNA pathways influence developmental timing and transitions that can control when postembryonic divisions occur. The variant affects a splice region (LOW predicted impact) but given VIG-1's role in timing of cell fate, altered VIG-1 could delay or block AMso division [Effect=splice_region_variant&intron_variant; IMPACT=LOW; QUALITY=22.1; MANUAL_DESCRIPTION_WB: vig-1 required for let-7 function].                                                                                                                 |                   |
# |      5 |                 0.35 |         0.3  | III:13307240 A>AG       | klp-19      | Predicted to enable ATP hydrolysis activity; microtubule binding activity; and microtubule motor activity. Involved in meiotic chromosome condensation and meiotic spindle midzone assembly. Located in condensed nuclear chromosome; nucleoplasm; and spindle. Expressed in germ line. Human ortholog(s) of this gene implicated in non-syndromic X-linked intellectual disability 100. Is an ortholog of human KIF4A (kinesin family member 4A) and KIF4B (kinesin family member 4B).                                                                                                                                                                                                                                                                                                  | klp-19 encodes a plus-end-directed microtubule motor protein that is most closely related to motors of the kinesin-4 family; KLP-19 activity is essential for embryonic and larval development and is required for generating a force that aligns sister chromatid kinetochores  directly opposite the spindle poles thus ensuring proper holocentric chromosome segregation; KLP-19 expression is detected in embryos and in the gonad, where it is most strongly expressed in distal mitotic nuclei and in late meiotic prophase nucleoplasm; during meiosis and mitosis, KLP-19 expression is dynamic and is detected in the nucleoplasm, the spindle body, in association with condensed chromosomes (particularly between homologous chromosomes), and in the spindle interzone.                                                                                                                                                                                                                                                                                                                                                                                                                                              | 5_prime_UTR_variant     | KLP-19 is a chromokinesin required for proper chromosome alignment and mitotic fidelity; although the variant is 5'UTR (LOW impact), altered expression of KLP-19 could compromise mitosis in AMso and prevent division. Given KLP-19's essential mitotic role in larvae, regulatory disruption is a plausible mechanistic route to Class II phenotypes, but the variant's non-coding annotation reduces confidence [Effect=5_prime_UTR_variant; IMPACT=LOW; QUALITY=25.5; MANUAL_DESCRIPTION_WB: KLP-19 required for mitotic chromosome behavior; GeneRef: PMID 37961478,15452142].                                                 |                   0.3  | KLP-19 is a chromokinesin required for proper chromosome alignment and mitotic fidelity in embryos and larvae; although the variant is 5'UTR (LOW impact), misregulation of klp-19 expression could impair AMso mitoses. The gene's mitotic role makes any damaging allele or regulatory change a credible cause of division failure [Effect=5_prime_UTR_variant; IMPACT=LOW; QUALITY=25.5; MANUAL_DESCRIPTION_WB: KLP-19 required for mitotic chromosome behavior; GeneRef: PMID 37961478,15452142].                                                                                                                    |                   |
# |      6 |                 0.3  |         0.3  | III:2770120 AGGGG>A     | laf-1       | Enables RNA strand annealing activity; identical protein binding activity; and molecular condensate scaffold activity. Involved in several processes, including masculinization of hermaphroditic germ-line; positive regulation of embryonic development; and positive regulation of fertilization. Located in P granule. Expressed in germ line. Human ortholog(s) of this gene implicated in colorectal cancer; hepatocellular carcinoma; and syndromic X-linked intellectual disability. Is an ortholog of human DDX3X (DEAD-box helicase 3 X-linked) and DDX3Y (DEAD-box helicase 3 Y-linked).                                                                                                                                                                                      | laf-1 encodes a DEAD-box RNA helicase; laf-1 is required for embryonic development and sex determination; laf-1 was identified in screens for dominant suppressors of the sterility produced by gain-of-function fem-3 mutations; when homozygous, laf-1 mutations result in embryonic and larval lethality and when heterozygous, feminization of XX and XO animals; reporter gene analyses indicate that wild-type laf-1 activity is required for proper translational repression of tra-2 mRNA via its 3'UTR; when expressed in embryos, LAF-1 localizes predominantly to the cytoplasm with additional localization seen in P granules.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        | 3_prime_UTR_variant     | LAF-1 is a DEAD-box RNA helicase required for translational control and embryonic development; a 3' UTR change could perturb LAF-1-mediated regulation of specific mRNAs (e.g., cell-cycle regulators), thereby interfering with AMso division. The variant is low-impact but LAF-1's role in translational repression makes it a plausible indirect regulator of the division event [Effect=3_prime_UTR_variant; IMPACT=LOW; QUALITY=25.1; MANUAL_DESCRIPTION_WB: laf-1 required for translational repression of tra-2; GeneRef: PMID 38218270].                                                                                    |                   0.3  | LAF-1 is a DEAD-box RNA helicase required for embryonic development and translational control; although the change is in the 3'UTR (LOW impact), LAF-1 affects translational repression (e.g., tra-2) and general RNA regulation. Misregulation could disrupt translation of cell-cycle regulators in AMso, providing a plausible indirect mechanism for blocking AMso division [Effect=3_prime_UTR_variant; IMPACT=LOW; QUALITY=25.1; MANUAL_DESCRIPTION_WB: laf-1 required for embryonic development and translational repression; GeneRef: PMID 38218270].                                                            |                   |
# ...
# |     17 |                 0.08 |         0.08 | X:2727138 TGGGGG>T      | unc-2       | Predicted to enable voltage-gated calcium channel activity. Involved in several processes, including determination of left/right asymmetry in nervous system; negative regulation of transforming growth factor beta receptor signaling pathway; and response to stress. Located in presynaptic active zone membrane. Expressed in several structures, including body wall musculature; excretory canal; nerve ring; neurons; and pharyngeal muscle cell. Used to study migraine. Human ortholog(s) of this gene implicated in autoimmune disease of the nervous system (multiple); brain disease (multiple); and episodic ataxia type 2. Is an ortholog of human CACNA1B (calcium voltage-gated channel subunit alpha1 B) and CACNA1E (calcium voltage-gated channel subunit alpha1 E). | unc-2 encodes a calcium channel alpha subunit similar to the human P/Q-type calcium channel, CACNA1A; unc-2 is required for desensitization to dopamine, normal movement, normally low sensitivity of whole animals to serotonin, and neuronal migrations; unc-2 interacts with the TGF beta pathway to regulate movement, and maintain normal serotonin levels; unc-2/TGF beta pathway is also required for the stress-induced modulation of tryptophan hydroxylase/tph-1 expression in the serotonergic chemosensory ADF neurons (but not the NSM neurons); UNC-2 is expressed primarily in motor neurons, several sensory neurons, and the HSN and VC neurons controlling egg-laying.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | intron_variant          | UNC-2 is a P/Q-type voltage-gated calcium channel; an intronic variant is unlikely to directly block AMso mitosis, although perturbation of neuronal signalling can sometimes feed back on glial development. This allele is therefore low probability as the causal lesion for a division failure phenotype [Effect=intron_variant; IMPACT=LOW; QUALITY=21.5; MANUAL_DESCRIPTION_WB: UNC-2 Ca2+ channel; GeneRefs: PMID 37160370,12878695].                                                                                                                                                                                         |                   0.08 | UNC-2 encodes a voltage-gated calcium channel alpha subunit important for neuronal activity, and the variant lies in an intron (LOW). This gene is central for neuronal physiology, but a direct role in AMso glial division is unlikely; nevertheless, neuronal-glial signalling can affect glial behaviours, so a low-probability indirect effect is possible [Effect=intron_variant; IMPACT=LOW; QUALITY=21.5; MANUAL_DESCRIPTION_WB: UNC-2 alpha channel; GeneRefs: PMID 37160370,12878695,16927961].                                                                                                                |                   |
# |     18 |                 0.07 |         0.07 | X:14187391 C>T          | ceh-36      | Enables RNA polymerase II transcription regulatory region sequence-specific DNA binding activity. Involved in neuron fate specification; positive regulation of transcription by RNA polymerase II; and sensory perception of chemical stimulus. Located in nucleus. Expressed in ABaraappa; ABaraappaa; amphid neurons; and head neurons. Is an ortholog of human ARGFX (arginine-fifty homeobox) and DPRX (divergent-paired related homeobox).                                                                                                                                                                                                                                                                                                                                         | ceh-36 encodes a paired-like homeodomain transcription factor that is one of three orthodenticle (OTX/OTD) homeodomain proteins in C. elegans (the others being TTX-1 and CEH-37); CEH-36 is required broadly for specification of the AWC olfactory neuron and also for establishing the left-right asymmetry of the ASEL and ASER gustatory neurons; in addition, CEH-36 is sufficient to specify the AFD thermosensory neuron fate in some cell types; CEH-36 is expressed in the AWC and ASE chemosensory neurons.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | upstream_gene_variant   | CEH-36 is an OTX-family homeodomain TF required for sensory neuron specification; the variant is upstream (LOW impact) so a direct protein-change mechanism is not indicated. However, misexpression of TFs can change developmental programs and might contribute to MCM specification defects (Class IV) more than a failure of AMso division (Class II) [Effect=upstream_gene_variant; IMPACT=LOW; QUALITY=43.8; MANUAL_DESCRIPTION_WB: CEH-36 OTX homeodomain TF; GeneRefs: PMID 15095973,20150279,25738873].                                                                                                                    |                   0.07 | CEH-36 is a homeodomain transcription factor required for sensory neuron fate specification; the variant is upstream (LOW), so direct disruption of protein function is not indicated. Still, homeodomain TFs influence neural identity and sometimes progenitor division programs, so a regulatory allele could contribute to subtype loss rather than division failure per se [Effect=upstream_gene_variant; IMPACT=LOW; QUALITY=43.8; MANUAL_DESCRIPTION_WB: CEH-36 OTX TF required for AWC/ASE specification; GeneRefs: PMID 15095973,20150279,25738873].                                                            |                   |
# |     19 |                 0.07 |         0.06 | V:20083824 G>A          | dcs-1       | Enables RNA 7-methylguanosine cap binding activity; hydrolase activity, acting on acid anhydrides; and sulfate adenylyltransferase (ADP) activity. Involved in several processes, including mRNA metabolic process; purine ribonucleotide metabolic process; and response to heat. Located in cytoplasm and nucleus. Is an ortholog of human DCPS (decapping enzyme, scavenger).                                                                                                                                                                                                                                                                                                                                                                                                         | dcs-1 encodes a scavenger mRNA decapping enzyme; DCS-1 exhibits hydrolase activity in vitro, with specificity for 7meGMP in its primary nucleoside monophosphate binding site; DCS-1 also exhibits sulfohydrolase and APS phosphorylase activity in vitro, catalyzing the formation of AMP and ADP from APS, respectively; dcs-1 is the upstream gene in an operon with fre-1, which encodes an NADPH-dependent flavin reductase; reporter fusions using dcs-1 upstream sequence direct expression throughout the life cycle in neurons and pharyngeal muscle; dcs-1 expression is also present in dauer larvae and enhanced by heat shock.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        | downstream_gene_variant | DCS-1 controls microRNA levels and thus affects post-transcriptional regulatory circuits; the observed downstream variant (LOW) is unlikely to be causal by itself but DCS-1 dysfunction is a plausible indirect regulator of developmental timing that might influence AMso division competence [Effect=downstream_gene_variant; IMPACT=LOW; QUALITY=5.6; MANUAL_DESCRIPTION_WB: DCS-1 decapping scavenger; GeneRefs: PMID 23966152,23541767].                                                                                                                                                                                      |                   0.06 | DCS-1 is the decapping scavenger enzyme that controls miRNA stability; a downstream change (LOW) is observed here, but perturbation of miRNA levels (DCS-1) can influence developmental timing and cell-fate programs. Because miRNA regulated timing can alter postembryonic events, DCS-1 is a plausible but lower-likelihood candidate [Effect=downstream_gene_variant; IMPACT=LOW; QUALITY=5.6; MANUAL_DESCRIPTION_WB: DCS-1 controls microRNA levels; GeneRefs: PMID 23966152,23541767].                                                                                                                            |                   |
# |     20 |                 0.06 |         0.06 | II:699012 C>T           | thoc-1      | Predicted to be involved in mRNA export from nucleus. Predicted to be part of THO complex part of transcription export complex. Human ortholog(s) of this gene implicated in autosomal dominant nonsyndromic deafness 86. Is an ortholog of human THOC1 (THO complex subunit 1).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | thoc-1 encodes the C. elegans ortholog of mammalian THOC1 and Drosophila and S. cerevisiae Hpr1, conserved subunits of the THO complex involved in mRNP biogenesis as part of transcription elongation, mRNA maturation, and export.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | upstream_gene_variant   | THOC-1 functions in mRNA biogenesis and export; an upstream variant may alter expression but is unlikely to be a specific cause of AMso division failure. Global mRNA-export defects often produce pleiotropic developmental phenotypes; therefore THOC-1 is a low-priority candidate without additional evidence [Effect=upstream_gene_variant; IMPACT=LOW; QUALITY=5.1; WB_Overview: THOC-1 part of THO complex].                                                                                                                                                                                                                  |                   0.05 | THOC-1 is part of the THO complex for mRNA biogenesis and export; an upstream variant (LOW) is present. Disruption of mRNA export can broadly alter gene expression including cell-cycle genes; however, the variant is non-coding and evidence for a specific AMso effect is weak [Effect=upstream_gene_variant; IMPACT=LOW; QUALITY=5.1; WB_Overview: THO complex subunit].                                                                                                                                                                                                                                            |                   |
#
# === Most likely causal variant (LLM) ===
# |   rank | variant_id     | gene   |   prob |   conf | narrative                                                                                                             |   narr_conf |
# |--------|----------------|--------|--------|--------|-----------------------------------------------------------------------------------------------------------------------|-------------|
# |      1 | X:13516823 C>T | cdk-4  |    0.9 |   0.85 | CDK-4 is a cyclin-dependent serine/threonine kinase required for G1 progression in postembryonic blast cells; a [...] |        0.85 |
#
# WROTE:
# - C:\Users\Kim_c\Desktop\codex\llm_variant_prioritization_outputs\llm_variant_ranking_20260206-173940.csv
# - C:\Users\Kim_c\Desktop\codex\llm_variant_prioritization_outputs\llm_variant_ranking_20260206-173940.jsonl
# - C:\Users\Kim_c\Desktop\codex\llm_variant_prioritization_outputs\llm_variant_ranking_merged_20260206-173940.csv
#
# [Post-merge diagnostics] Missing-by-column (should be near zero if mapping_output join succeeded):
# {'protein_change': 0, 'ems_label_raw': 0, 'parental_ratio': 0, 'hawaiian_ratio': 0, 'qual': 0, 'depth': 0}
